# %%
import torch


list = torch.tensor([1, 1, 2, 2, 3, 3])

print(list) 
print(list.unique())  # tensor([1, 2, 3])，unique() 函数返回输入张量中唯一的元素，去除重复值后得到一个新的张量，其中包含了输入张量中的所有不同的元素。
# Out:
# tensor([1, 1, 2, 2, 3, 3])
# tensor([1, 2, 3])
